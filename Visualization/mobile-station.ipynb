# %%
import numpy as np 
import matplotlib.pyplot as plt
import warnings
from scipy import interpolate

warnings.filterwarnings('ignore')
np.random.seed(19)

# %%
resolution = 10
length = 100

cluster = {}
number = {}
colour = {}
SIGMA = {}
u = {}
label = {}
#font = {'family': 'Palatino',}
font = {}

# %%
u['cluster1'] = [np.random.randint(20,80), np.random.randint(20,80)]
SIGMA['cluster1'] = 7
number['cluster1'] = 250
colour ['cluster1'] =  '#9400D3'
cluster['cluster1'] = np.zeros((number['cluster1'],3))
cluster['cluster1'] [:,0:1] = np.floor((np.random.randn(number['cluster1'],1)*SIGMA['cluster1'] + u['cluster1'][0])%length)
cluster['cluster1'] [:,1:2] = np.floor((np.random.randn(number['cluster1'],1)*SIGMA['cluster1'] + u['cluster1'][1])%length)
label['cluster1'] = 'MS cluster 1'

u['cluster2'] = [np.random.randint(30,80), np.random.randint(20,70)]
SIGMA['cluster2'] = 10
number['cluster2'] = 300
colour ['cluster2'] =  '#FF8C00'
cluster['cluster2'] = np.zeros((number['cluster2'],3))
cluster['cluster2'] [:,0:1] = np.floor((np.random.randn(number['cluster2'],1)*SIGMA['cluster2'] + u['cluster2'][0])%length)
cluster['cluster2'] [:,1:2] = np.floor((np.random.randn(number['cluster2'],1)*SIGMA['cluster2'] + u['cluster2'][1])%length)
label['cluster2'] = 'MS cluster 2'


u['cluster3'] = [np.random.randint(10,85), np.random.randint(10,90)]
SIGMA['cluster3'] = 6
number['cluster3'] = 200
colour ['cluster3'] =  '#228B22'
cluster['cluster3'] = np.zeros((number['cluster3'],3))
cluster['cluster3'] [:,0:1] = np.floor((np.random.randn(number['cluster3'],1)*SIGMA['cluster3'] + u['cluster3'][0])%length)
cluster['cluster3'] [:,1:2] = np.floor((np.random.randn(number['cluster3'],1)*SIGMA['cluster3'] + u['cluster3'][1])%length)
label['cluster3'] = 'MS cluster 3'

number['uniform'] = 300
cluster['uniform'] = np.random.randint(0,100,size=[number['uniform'],3])
colour ['uniform'] = '#4169E1'
label['uniform'] = 'MS uniform'

# %%
fig, ax = plt.subplots(figsize=(5, 5))
plt.xlim((0,100)) #设置坐标轴范围
plt.xticks(np.arange(0,100,10))
plt.yticks(np.arange(0,100,10))
plt.ylim((0,100))
ax.grid(ls='--',c='#D3D3D3')
for dic in cluster:
    scale = 10.0 * np.ones(number[dic])
    color = colour [dic]
    ax.scatter(cluster[dic][:,0], cluster[dic][:,1], c=colour[dic], s=scale, label=label[dic],
                   alpha=0.3, edgecolors='none')

ax.legend()
plt.xlabel('Location (meter)', font)
plt.ylabel('Location (meter)', font)
fig.savefig('cluster_ms.eps',dpi=600,format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
fig, ax = plt.subplots(figsize=(5, 5))
plt.xlim((0,100)) #设置坐标轴范围
plt.ylim((0,100))
plt.xticks(np.arange(0,100,10))
plt.yticks(np.arange(0,100,10))
ax.grid(ls='--',c='#D3D3D3')
for dic in cluster:
    scale = 10.0 * np.ones(number[dic])
    color = colour [dic]
    if dic != 'uniform':
        ax.scatter(cluster[dic][:,0], cluster[dic][:,1], c='#D2691E', s=scale, alpha=0.3, edgecolors='none')
    else:
        ax.scatter(cluster[dic][:,0], cluster[dic][:,1], c='#D2691E', s=scale, label='Mobile Station',
                   alpha=0.3, edgecolors='none')
ax.legend()
plt.xlabel('Location (meter)', font)
plt.ylabel('Location (meter)', font)
fig.savefig('all_ms.eps',dpi=600,format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
density = np.zeros((length,length))
for j in range (length):
    for i in range (length):
        for dic in cluster:
            for k in range (number[dic]):
                if abs(int(cluster[dic][k,0])-i)<=5 and abs(int(cluster[dic][k,1])-j)<=5:
                    density[j,i] += 1

# %%
# 数据数目
n = 100
# 定义x, y
x = np.linspace(0, 100, n)
y = np.linspace(0, 100, n)

# 生成网格数据
X, Y = np.meshgrid(x, y)
fig, ax = plt.subplots(figsize=(5,5))
plt.xlim((0,100)) #设置坐标轴范围
plt.ylim((0,100))
plt.xticks(np.arange(0,100,10))
plt.yticks(np.arange(0,100,10))
# 填充等高线的颜色, 8是等高线分为几部分
plt.contourf(X, Y, np.around(density, -1)/40, 6, alpha = 0.85, cmap = plt.cm.Blues)
# 绘制等高线
plt.grid(ls='--',c='#D3D3D3')
C = plt.contour(X, Y, np.around(density, -1)/40, 6, colors = 'black', linewidth = 0.01)
# 绘制等高线数据
plt.xlabel('Location (meter)', font)
plt.ylabel('Location (meter)', font)
plt.clabel(C, inline = True, fontsize = 6)
fig.savefig('isoheight.eps',dpi=600,format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
transter = np.ones(length)
x = np.dot(density,transter)/40
transter = np.ones(length)
y = np.dot(density.transpose(),transter)/40

# %%
n = np.linspace(0, 100, 100)
fig, ax = plt.subplots(figsize=(5,5))
plt.xlim((0,100)) #设置坐标轴范围
plt.ylim((0,100))
plt.xticks(np.arange(0,100,10))
plt.yticks(np.arange(0,100,10))
plt.grid(ls='--',c='#D3D3D3')


nnew = np.linspace(n.min(),n.max(),1000) #300 represents number of points to make between T.min and T.max
func = interpolate.interp1d(n,x,kind='cubic')
x_smooth = func(nnew)

# Using set_dashes() to modify dashing of an existing line
line1, = ax.plot(nnew, x_smooth, label='MS width distribution')
line1.set_dashes([2, 2, 10, 2])  # 2pt line, 2pt break, 10pt line, 2pt break

# Using plot(..., dashes=...) to set the dashing when creating a line
line2, = ax.plot(n, y , dashes=[6, 2], label='MS length distribution')
plt.clabel(C, inline = True, fontsize = 6)

plt.xlabel('Location (meter)',font)
plt.ylabel('MS (device)',font)
ax.legend()
plt.show()
fig.savefig('line_distribution.eps',dpi=600,format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
for dict in cluster:
    print(dict)
    if dict == 'cluster1':
        user = cluster[dict]
    else: 
        user = np.concatenate((user,cluster[dict]),axis=0)
# Out:
# cluster1
# cluster2
# cluster3
# uniform

# %%
y2_SARSA = np.load('SARSA2drone1050ms.npy')/10.5
y2_Q = np.load('Q2drone1050ms.npy')/10.5
y2_KMeans = np.load('KMeans2drone1050ms.npy')/10.5
x = np.linspace(0,99,100)
best2 = np.ones(100)*506/10.5
average2 = np.ones(100)*173/10.5

# %%
fig, ax = plt.subplots(figsize=(5,5))
plt.xlim((0,100)) #设置坐标轴范围
plt.ylim((5,50))
plt.xticks(np.arange(0,100,10))
plt.yticks(np.arange(10,50,4.5))
plt.grid(ls='--',c='#D3D3D3')
# line1_SARSA, = ax.plot(x, y2_SARSA, label='SARSA performance', color='#1E90FF')
# line1_Q, = ax.plot(x, y2_Q, label='Q-Learning performance', color='#FF8C00')
line1_SARSA, = ax.plot(x, y2_SARSA, label='SARSA performance')
line1_Q, = ax.plot(x, y2_Q, label='Q-Learning performance')
line1_KMeans, = ax.plot(x, y2_KMeans, label='K-Means performance')
line2, = ax.plot(x, best2, dashes=[6, 2], label='Theoretical best performance', color='#F08080')
line3, = ax.plot(x, average2, dashes=[6, 2], label='Random position performance', color='#20B2AA')
plt.xlabel('Episode',font)
plt.ylabel('Connected MS Percentage (%)',font)
ax.legend()
plt.show()
fig.savefig('2drone1050ms.eps',dpi=600,format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
y4_SARSA = np.load('SARSA4drone1050ms.npy')/10.5
y4_Q = np.load('Q4drone1050ms.npy')/10.5
y4_KMeans = np.load('KMeans4drone1050ms.npy')/10.5
x = np.linspace(0,99,100)
best4 = np.ones(100)*765/10.5
average4 = np.ones(100)*290/10.5

# %%
fig, ax = plt.subplots(figsize=(5,5))
plt.xlim((0,100)) #设置坐标轴范围
plt.ylim((10,75))
plt.xticks(np.arange(0,100,10))
plt.yticks(np.arange(10,75,6.5))
plt.grid(ls='--',c='#D3D3D3')
# line1_SARSA, = ax.plot(x, y4_SARSA, label='SARSA performance', color='#4682B4')
line1_SARSA, = ax.plot(x, y4_SARSA, label='SARSA performance')
line1_Q, = ax.plot(x, y4_Q, label='Q-Learning performance')
line1_KMeans, = ax.plot(x, y4_KMeans, label='K-Means performance')
line2, = ax.plot(x, best4, dashes=[6, 2], label='Theoretical best performance', color='#F08080')
line3, = ax.plot(x, average4, dashes=[6, 2], label='Random position performance', color='#20B2AA')
plt.xlabel('Episode',font)
plt.ylabel('Connected MS Percentage (%)',font)
ax.legend()
plt.show()
fig.savefig('4drone1050ms.eps',dpi=600,format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
y8_SARSA = np.load('SARSA8drone1050ms.npy')/10.5
y8_Q = np.load('Q8drone1050ms.npy')/10.5
y8_KMeans = np.load('KMeans8drone1050ms.npy')/10.5
x = np.linspace(0,99,100)
best8 = np.ones(100)*867/10.5
average8 = np.ones(100)*392/10.5

# %%
fig, ax = plt.subplots(figsize=(5,5))
plt.xlim((0,100)) #设置坐标轴范围
plt.ylim((20,85))
plt.xticks(np.arange(0,100,10))
plt.yticks(np.arange(20,85,6.5))
plt.grid(ls='--',c='#D3D3D3')
# line1, = ax.plot(x, y8_SARSA, label='SARSA performance', color='#6A5ACD')
line1_SARSA, = ax.plot(x, y8_SARSA, label='SARSA performance')
line1_Q, = ax.plot(x, y8_Q, label='Q-Learning performance')
line1_KMeans, = ax.plot(x, y8_KMeans, label='K-Means performance')
line2, = ax.plot(x, best8, dashes=[6, 2], label='Theoretical best performance', color='#F08080')
line3, = ax.plot(x, average8, dashes=[6, 2], label='Random position performance', color='#20B2AA')
plt.xlabel('Episode',font)
plt.ylabel('Connected MS Percentage (%)',font)
ax.legend()
plt.show()
fig.savefig('8drone1050ms.eps',dpi=600,format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
comp2_SARSA =  best2 - y2_SARSA
comp4_SARSA =  best4 - y4_SARSA
comp8_SARSA =  best8 - y8_SARSA
comp2_Q =  best2 - y2_Q
comp4_Q =  best4 - y4_Q
comp8_Q =  best8 - y8_Q
comp2_KMeans =  best2 - y2_KMeans
comp4_KMeans =  best4 - y4_KMeans
comp8_KMeans =  best8 - y8_KMeans
x = np.linspace(0,99,100)

# %%
fig, ax = plt.subplots(figsize=(5,5))
plt.xlim((0,100)) #设置坐标轴范围
plt.ylim((5,55))
plt.xticks(np.arange(0,100,10))
plt.yticks(np.arange(5,55,5))
plt.grid(ls='--',c='#D3D3D3')
# line1, = ax.plot(x, comp2, label='2 drone SARSA', color='#1E90FF')
# line2, = ax.plot(x, comp4, label='4 drone SARSA', color='#4682B4')
# line3, = ax.plot(x, comp8, label='8 drone SARSA', color='#6A5ACD')
line1_SARSA, = ax.plot(x, comp2_SARSA, label='2 drone SARSA')
line1_Q, = ax.plot(x, comp2_Q, label='2 drone Q-Learning')
line1_KMeans, = ax.plot(x, comp2_KMeans, label='2 drone K-Means')
line2_SARSA, = ax.plot(x, comp4_SARSA, label='4 drone SARSA')
line2_Q, = ax.plot(x, comp4_Q, label='4 drone Q-Learning')
line2_KMeans, = ax.plot(x, comp4_KMeans, label='4 drone K-Means')
line3_SARSA, = ax.plot(x, comp8_SARSA, label='8 drone SARSA')
line3_Q, = ax.plot(x, comp8_Q, label='8 drone Q-Learning')
line3_KMeans, = ax.plot(x, comp8_KMeans, label='8 drone K-Means')
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)

plt.xlabel('Episode',font)
plt.ylabel('Difference Between TBP and RL (%)',font)
ax.legend()
plt.show()
fig.savefig('All_difference.eps',dpi=600,format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
